# %% [markdown]
# # SQL Murder Mystery

# %% [markdown]
# Reporte de la ciudad del dia del crimen:

# %%
SELECT * 
FROM crime_scene_report 
WHERE date=20180115 and city='SQL City'

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Las dos personas que han sido testigas son estas (sacadas del reporte)

# %%
SELECT * 
FROM person 
WHERE address_street_name='Northwestern Dr' 
ORDER BY address_number DESC

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
SELECT * 
FROM person 
WHERE address_street_name='Franklin Ave' and name LIKE 'Annabel%'

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Declaración de Morty:

# %%
SELECT * 
FROM interview 
WHERE person_id = 14887

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Declaración de Annabel:

# %%
SELECT * 
FROM interview 
WHERE person_id = 16371

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Sigiendo las declaraciones de Morty:
# - Buscamos los socios del gimnasio que tengan un numero que empieze por 48Z...
# - Nos quedamos con los "GOLD"

# %%
SELECT * 
FROM get_fit_now_member 
WHERE id LIKE '48Z%'

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### Tenemos dos possibles sospechosos:
# + Joe Germuska
# + Jeremy Bowers

# %%
SELECT * FROM person WHERE id = 28819 or id = 67318

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Sigiendo las declaraciones de Morty:
# + El asesino entró en el coche cuya matrícula contenía los caracteres "H42W"

# %%
SELECT * 
FROM drivers_license
WHERE id = 173289 or id = 423327

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ##### Sospechoso --> Jeremy Bowers

# %% [markdown]
# Sigiendo las declaraciones de Annabel:
# + ¿Estaba en el gimnasio Jeremy el 9 de Enero?

# %%
SELECT * 
FROM get_fit_now_check_in 
WHERE membership_id = "48Z55"

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### PRINCIPAL SOSPECHOSO --> Jeremy Bowers

# %% [markdown]
# Entrevista a Jeremy Bowers sobre qué hizo el día del asesinato:

# %%
SELECT * 
FROM interview 
WHERE person_id = 67318

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <span style="background-color: red;">*Jeremy Bowers* es el **sicario** </span>  pero... quien lo contrató?

# %%
SELECT * 
FROM drivers_license
WHERE hair_color ="red" and car_make = "Tesla" and gender = "female"

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
SELECT * 
FROM person
WHERE license_id = 202298 or license_id = 291182 or license_id = 918773

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Según las declaraciones del sicario, la mujer que lo contrató estubo en la SQL Symphony Concert, tres veces en Diciembre 1017:
# + Comprobamos los tres id y solo Miranda Priestly coincide

# %%
SELECT * 
FROM facebook_event_checkin
WHERE event_name = "SQL Symphony Concert" and person_id = 99716 and date between 20171201 and 20171231

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Y tiene dinero:

# %%
SELECT * 
FROM income
WHERE ssn = 987756388

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <span style="background-color: red;">*Jeremy Bowers* mató por ordenes de **Miranda Priestly** </span>

# %% [markdown]
# El día del asesinato, Jeremy Bowers estubo en The Funky Grooves Tour:

# %%
SELECT * 
FROM facebook_event_checkin
WHERE event_id = 4719 and date = 20180115

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# y coincidió con los testigos:
# + 14887 = Annabel
# + 16371 = Morty

# %% [markdown]
# <span style="background-color: red;">*Jeremy Bowers* disparó a la victima por ordenes de **Miranda Priestly** en *The Funky Grooves Tour* </span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
