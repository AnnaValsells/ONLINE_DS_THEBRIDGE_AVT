# %%
import numpy as np
import pandas as pd

# %%
df_agility = pd.read_csv("./data/agility_runs_df.csv")
# Out:
# C:\Users\annav\AppData\Local\Temp\ipykernel_5784\538828378.py:1: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_agility = pd.read_csv("./data/agility_runs_df.csv")

# %%
# Descartamos competiciones en Mexico que no tienen nº Licencia:
df_agility.loc[df_agility["License"].isna()]

df_agility.dropna(axis="index", inplace=True)
df_agility.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32771 entries, 0 to 32793
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      32771 non-null  int64
#  1   Indice          32771 non-null  int64
#  2   Index_data      32771 non-null  int64
#  3   Fecha           32771 non-null  object
#  4   Manga           32771 non-null  object
#  5   License         32771 non-null  object
#  6   Breed           32771 non-null  object
#  7   Gender          32771 non-null  object
#  8   Hight_cm        32771 non-null  float64
#  9   Classification  32771 non-null  object
#  10  Qualification   32771 non-null  object
#  11  Speed           32771 non-null  object
#  12  Time            32771 non-null  object
#  13  Faults          32771 non-null  object
#  14  Refusals        32771 non-null  object
#  15  Competition     32771 non-null  object
#  16  Location        32771 non-null  object
#  17  Roof            32771 non-null  object
#  18  Floor           32771 non-null  object
# dtypes: float64(1), int64(3), object(15)
# memory usage: 5.0+ MB

# %%
# 2753 participantes 
df_agility["License"].describe()
# Out:
# count     32771
# unique     2753
# top       15936
# freq        129
# Name: License, dtype: object

# %%
# 620 competiciones
# 32771 pistas
df_agility["Competition"].describe()
# Out:
# count                          32771
# unique                           620
# top       RSCE Club Agility Ourencan
# freq                             277
# Name: Competition, dtype: object

# %%
df_agility
# Out:
#        Unnamed: 0  Indice  Index_data                                  Fecha  \
# 0               0       0           0                         Sabado 6 abril
# 1               1       1           0                         Sabado 6 abril
# 2               2       2           0                         Sabado 6 abril
# 3               3       3           0                         Sabado 6 abril
# 4               4       4           0                         Sabado 6 abril
# ...           ...     ...         ...                                    ...
# 32789       35555   35555         680  7ª Prova Camp. Nac. Agility 2021/2022
# 32790       35556   35556         680  7ª Prova Camp. Nac. Agility 2021/2022
# 32791       35557   35557         680  7ª Prova Camp. Nac. Agility 2021/2022
# 32792       35558   35558         680  7ª Prova Camp. Nac. Agility 2021/2022
# 32793       35559   35559         680  7ª Prova Camp. Nac. Agility 2021/2022
#
#          Manga               License                    Breed  Gender  \
# 0      Jumping  2023280386PS88000015  Continental Toy Spaniel    Male
# 1      Agility  2023280386PS88000015  Continental Toy Spaniel    Male
# 2      Jumping  2022160138RS70000004        Shetland Sheepdog  Female
# 3      Agility  2022160138RS70000004        Shetland Sheepdog  Female
# 4      Jumping  2018160135RS70000001            Border Collie  Female
# ...        ...                   ...                      ...     ...
# 32789  Jumping                  2300              Mixed breed  Female
# 32790  Agility                  1995                     Mudi  Female
# 32791  Jumping                  1995                     Mudi  Female
# 32792  Agility                  2606            Border Collie  Female
# 32793  Jumping                  2606            Border Collie  Female
#
#        Hight_cm Classification Qualification     Speed     Time Faults  \
# 0          24.5              -          DISQ         -        -      -
# 1          24.5              -            NQ  2.48 m/s  79.88 s      2
# 2          31.0             1º        V_GOOD  3.59 m/s  42.03 s      1
# 3          31.0              -          DISQ         -        -      -
# 4          50.0              -          DISQ         -        -      -
# ...         ...            ...           ...       ...      ...    ...
# 32789      30.5              -          DISQ         -        -      -
# 32790      38.0             1º         EXC_0  5.63 m/s  38.87 s      -
# 32791      38.0              -          DISQ         -        -      -
# 32792      50.5             3º           EXC  5.63 m/s  38.91 s      1
# 32793      50.5             2º         EXC_0  5.82 m/s  36.23 s      -
#
#       Refusals                                     Competition  \
# 0            -  Pataplán 6 y 7 Abril - Liga CASTILLA LA MANCHA
# 1            2  Pataplán 6 y 7 Abril - Liga CASTILLA LA MANCHA
# 2            1  Pataplán 6 y 7 Abril - Liga CASTILLA LA MANCHA
# 3            -  Pataplán 6 y 7 Abril - Liga CASTILLA LA MANCHA
# 4            -  Pataplán 6 y 7 Abril - Liga CASTILLA LA MANCHA
# ...        ...                                             ...
# 32789        -                    Agility Cantabria - Out 2021
# 32790        -                    Agility Cantabria - Out 2021
# 32791        -                    Agility Cantabria - Out 2021
# 32792        -                    Agility Cantabria - Out 2021
# 32793        -                    Agility Cantabria - Out 2021
#
#               Location     Roof          Floor
# 0       Cuenca / Spain  Outdoor           Sand
# 1       Cuenca / Spain  Outdoor           Sand
# 2       Cuenca / Spain  Outdoor           Sand
# 3       Cuenca / Spain  Outdoor           Sand
# 4       Cuenca / Spain  Outdoor           Sand
# ...                ...      ...            ...
# 32789  Elechas / Spain  Outdoor  Natural grass
# 32790  Elechas / Spain  Outdoor  Natural grass
# 32791  Elechas / Spain  Outdoor  Natural grass
# 32792  Elechas / Spain  Outdoor  Natural grass
# 32793  Elechas / Spain  Outdoor  Natural grass
#
# [32771 rows x 19 columns]

# %%
df_agility.drop(columns = ["Unnamed: 0", "Indice"], inplace = True)

# %%
df_agility.to_csv("DATA_AGILITY.csv")
