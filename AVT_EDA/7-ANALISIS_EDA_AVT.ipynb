# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
sns.set(color_codes=True)

# %%
df_agility = pd.read_csv("./data/6_DATA_AGILITY.csv")

# %%
df_agility.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32611 entries, 0 to 32610
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   indice             32611 non-null  int64
#  1   Index_data         32611 non-null  int64
#  2   Fecha              32611 non-null  object
#  3   License            32611 non-null  object
#  4   Breed              32611 non-null  object
#  5   Gender             32611 non-null  object
#  6   Hight_cm           32611 non-null  float64
#  7   Classification     32611 non-null  object
#  8   Speed              32611 non-null  object
#  9   Time               32611 non-null  object
#  10  Faults             32611 non-null  object
#  11  Refusals           32611 non-null  object
#  12  Competition        32611 non-null  object
#  13  Location           32611 non-null  object
#  14  Roof               32611 non-null  object
#  15  Floor              32611 non-null  object
#  16  Eliminados         32611 non-null  object
#  17  Fecha_Competición  32611 non-null  object
#  18  Pista              32611 non-null  object
# dtypes: float64(1), int64(2), object(16)
# memory usage: 4.7+ MB

# %% [markdown]
# ### Hipotesis 1.1: Los perros de raza border collie no ganan más que los perros de otras razas.

# %%
df_agility.groupby(df_agility["Breed"] == "Border Collie")["Classification"].value_counts()
# Out:
# Breed  Classification
# False  1º                10977
#        -                  6581
#        2º                 2455
#        3º                  769
#        4º                  328
#        5º                   84
#        6º                   63
#        8º                   19
#        7º                   16
#        10º                   2
#        9º                    2
#        11º                   1
# True   1º                 5597
#        -                  2831
#        2º                 1705
#        3º                  649
#        4º                  305
#        5º                  111
#        6º                   65
#        7º                   26
#        8º                   17
#        10º                   4
#        9º                    4
# Name: count, dtype: int64

# %%
razas_20 = df_agility["Breed"].value_counts()[:20]
razas_20
# Out:
# Breed
# Border Collie                             11314
# Shetland Sheepdog                          4426
# Mixed breed                                3043
# Spanish Water Dog                          1815
# Poodle                                     1631
# English Cocker Spaniel                     1361
# Jack Russell Terrier                       1123
# Belgian Shepherd Dog                        865
# Parson Russell Terrier                      694
# Mudi                                        490
# Continental Toy Spaniel                     484
# Miniature Pinscher                          427
# Schnauzer                                   413
# Andalusian wine-cellar rat-hunting dog      313
# German Spitz                                306
# Mini American Shepherd                      290
# Australian Kelpie                           246
# Australian Shepherd                         205
# Chihuahua                                   184
# Pyrenean Sheepdog - Smooth Faced            166
# Name: count, dtype: int64

# %%
# de 32611 pistas, 11314 son realizadas por Border Collies.
fig = plt.plot(figsize= (100,50))
sns.barplot(y= razas_20.index, x= razas_20.values, hue= razas_20.values, legend=False, palette= "tab20b")
fig
# Out:
# []

# %%
razas_20_podium = pd.DataFrame(razas_20)
dic_podium = {
    "Primero":[],
    "Segundo":[],
    "Tercero":[]
}
for raza in razas_20_podium.index:
    podium_x_raza = df_agility.groupby(df_agility["Breed"] == raza)["Classification"].value_counts()
    for a,b in podium_x_raza.items():
        if a == (True, '1º'):
            dic_podium["Primero"].append(b)
        if a == (True, '2º'):
            dic_podium["Segundo"].append(b)
        if a == (True, '3º'):
            dic_podium["Tercero"].append(b)

# Los chiuauas no tienen podim en bronce (3ª)
df_agility.groupby(df_agility["Breed"] == "Chihuahua")["Classification"].value_counts()
# Out:
# Breed  Classification
# False  1º                16460
#        -                  9348
#        2º                 4154
#        3º                 1418
#        4º                  633
#        5º                  195
#        6º                  128
#        7º                   42
#        8º                   36
#        10º                   6
#        9º                    6
#        11º                   1
# True   1º                  114
#        -                    64
#        2º                    6
# Name: count, dtype: int64

# %%
dic_podium["Tercero"] = np.insert(dic_podium["Tercero"], 18, 0)

# %%
razas_20_podium["Primero"] = dic_podium["Primero"]
razas_20_podium["Segundo"] = dic_podium["Segundo"]
razas_20_podium["Tercero"] = dic_podium["Tercero"]
razas_20_podium["Suma_Podiums"] = razas_20_podium["Primero"] + razas_20_podium["Segundo"] + razas_20_podium["Tercero"]

# %%
razas_20_podium = razas_20_podium.sort_values(by="Suma_Podiums", ascending=False)

# %%
razas_20_podium["%Absoluto"] = razas_20_podium["Suma_Podiums"] / 32611 *100 
razas_20_podium["%Relativo"] = razas_20_podium["Suma_Podiums"] / razas_20_podium["count"] *100

# %%
razas_20_podium
# Out:
#                                         count  Primero  Segundo  Tercero  \
# Breed
# Border Collie                           11314     5597     1705      649
# Shetland Sheepdog                        4426     2286      511      129
# Mixed breed                              3043     1512      324      110
# Spanish Water Dog                        1815      942      197       71
# Poodle                                   1631      891      217       40
# English Cocker Spaniel                   1361      685       92       41
# Jack Russell Terrier                     1123      614      109       28
# Belgian Shepherd Dog                      865      434      132       58
# Parson Russell Terrier                    694      356       67       23
# Miniature Pinscher                        427      270       45        2
# Mudi                                      490      255       37       17
# Schnauzer                                 413      232       58       15
# Continental Toy Spaniel                   484      239       45        8
# German Spitz                              306      185       24        2
# Andalusian wine-cellar rat-hunting dog    313      148       23        9
# Mini American Shepherd                    290      129       35       16
# Australian Kelpie                         246       91       30       24
# Pyrenean Sheepdog - Smooth Faced          166       99       30        2
# Australian Shepherd                       205       87       26       12
# Chihuahua                                 184      114        6        0
#
#                                         Suma_Podiums  %Absoluto  %Relativo
# Breed
# Border Collie                                   7951  24.381344  70.275765
# Shetland Sheepdog                               2926   8.972433  66.109354
# Mixed breed                                     1946   5.967312  63.950049
# Spanish Water Dog                               1210   3.710404  66.666667
# Poodle                                          1148   3.520285  70.386266
# English Cocker Spaniel                           818   2.508356  60.102866
# Jack Russell Terrier                             751   2.302904  66.874443
# Belgian Shepherd Dog                             624   1.913465  72.138728
# Parson Russell Terrier                           446   1.367637  64.265130
# Miniature Pinscher                               317   0.972065  74.238876
# Mudi                                             309   0.947533  63.061224
# Schnauzer                                        305   0.935267  73.849879
# Continental Toy Spaniel                          292   0.895403  60.330579
# German Spitz                                     211   0.647021  68.954248
# Andalusian wine-cellar rat-hunting dog           180   0.551961  57.507987
# Mini American Shepherd                           180   0.551961  62.068966
# Australian Kelpie                                145   0.444635  58.943089
# Pyrenean Sheepdog - Smooth Faced                 131   0.401705  78.915663
# Australian Shepherd                              125   0.383306  60.975610
# Chihuahua                                        120   0.367974  65.217391

# %%
# En terminos relativos
podium_relativo = razas_20_podium.sort_values(by="%Relativo", ascending=False)

fig = plt.plot(figsize= (100,50))
sns.barplot(y= podium_relativo.index, x= podium_relativo["%Relativo"], hue= podium_relativo["%Relativo"], legend=False, palette= "tab20b")
fig
# Out:
# []

# %%
# En terminos absolutos
podium_absoluto = razas_20_podium.sort_values(by="%Absoluto", ascending=False)

fig = plt.plot(figsize= (100,50))
sns.barplot(y= podium_absoluto.index, x= podium_absoluto["%Absoluto"], hue= podium_absoluto["%Absoluto"], legend=False, palette= "tab20b")
fig
# Out:
# []

# %%
dic_elim = {
    "pistas_a_0" : [],
    "eliminados" : []
}

for raza in razas_20_podium.index:
    elim_x_raza = df_agility.groupby(df_agility["Breed"] == raza)["Eliminados"].value_counts()
    for a,b in elim_x_raza.items():
        if a == (True, 'EXC_0'):
            dic_elim["pistas_a_0"].append(b)
        if a == (True, 'ELIM'):
            dic_elim["eliminados"].append(b)

# %%
razas_20_podium["pistas_a_0"] = dic_elim["pistas_a_0"]
razas_20_podium["eliminados"] = dic_elim["eliminados"]

# %%
razas_20_podium["%Pisats_a_0"] =  razas_20_podium["pistas_a_0"] / razas_20_podium["count"] *100
razas_20_podium["%eliminados"] =  razas_20_podium["eliminados"] / razas_20_podium["count"] *100

# %%
razas_20_podium
# Out:
#                                         count  Primero  Segundo  Tercero  \
# Breed
# Border Collie                           11314     5597     1705      649
# Shetland Sheepdog                        4426     2286      511      129
# Mixed breed                              3043     1512      324      110
# Spanish Water Dog                        1815      942      197       71
# Poodle                                   1631      891      217       40
# English Cocker Spaniel                   1361      685       92       41
# Jack Russell Terrier                     1123      614      109       28
# Belgian Shepherd Dog                      865      434      132       58
# Parson Russell Terrier                    694      356       67       23
# Miniature Pinscher                        427      270       45        2
# Mudi                                      490      255       37       17
# Schnauzer                                 413      232       58       15
# Continental Toy Spaniel                   484      239       45        8
# German Spitz                              306      185       24        2
# Andalusian wine-cellar rat-hunting dog    313      148       23        9
# Mini American Shepherd                    290      129       35       16
# Australian Kelpie                         246       91       30       24
# Pyrenean Sheepdog - Smooth Faced          166       99       30        2
# Australian Shepherd                       205       87       26       12
# Chihuahua                                 184      114        6        0
#
#                                         Suma_Podiums  %Absoluto  %Relativo  \
# Breed
# Border Collie                                   7951  24.381344  70.275765
# Shetland Sheepdog                               2926   8.972433  66.109354
# Mixed breed                                     1946   5.967312  63.950049
# Spanish Water Dog                               1210   3.710404  66.666667
# Poodle                                          1148   3.520285  70.386266
# English Cocker Spaniel                           818   2.508356  60.102866
# Jack Russell Terrier                             751   2.302904  66.874443
# Belgian Shepherd Dog                             624   1.913465  72.138728
# Parson Russell Terrier                           446   1.367637  64.265130
# Miniature Pinscher                               317   0.972065  74.238876
# Mudi                                             309   0.947533  63.061224
# Schnauzer                                        305   0.935267  73.849879
# Continental Toy Spaniel                          292   0.895403  60.330579
# German Spitz                                     211   0.647021  68.954248
# Andalusian wine-cellar rat-hunting dog           180   0.551961  57.507987
# Mini American Shepherd                           180   0.551961  62.068966
# Australian Kelpie                                145   0.444635  58.943089
# Pyrenean Sheepdog - Smooth Faced                 131   0.401705  78.915663
# Australian Shepherd                              125   0.383306  60.975610
# Chihuahua                                        120   0.367974  65.217391
#
#                                         pistas_a_0  eliminados  %Pisats_a_0  \
# Breed
# Border Collie                                 4166        2728    36.821637
# Shetland Sheepdog                             1629        1376    36.805242
# Mixed breed                                    901         950    29.608939
# Spanish Water Dog                              684         523    37.685950
# Poodle                                         749         458    45.922747
# English Cocker Spaniel                         516         513    37.913299
# Jack Russell Terrier                           373         346    33.214604
# Belgian Shepherd Dog                           264         192    30.520231
# Parson Russell Terrier                         257         233    37.031700
# Miniature Pinscher                             201          98    47.072600
# Mudi                                           178         165    36.326531
# Schnauzer                                      171          90    41.404358
# Continental Toy Spaniel                        173         187    35.743802
# German Spitz                                   140          87    45.751634
# Andalusian wine-cellar rat-hunting dog          92         119    29.392971
# Mini American Shepherd                          92         103    31.724138
# Australian Kelpie                               88          81    35.772358
# Pyrenean Sheepdog - Smooth Faced                95          32    57.228916
# Australian Shepherd                             31          72    15.121951
# Chihuahua                                       81          60    44.021739
#
#                                         %eliminados
# Breed
# Border Collie                             24.111720
# Shetland Sheepdog                         31.089019
# Mixed breed                               31.219192
# Spanish Water Dog                         28.815427
# Poodle                                    28.080932
# English Cocker Spaniel                    37.692873
# Jack Russell Terrier                      30.810329
# Belgian Shepherd Dog                      22.196532
# Parson Russell Terrier                    33.573487
# Miniature Pinscher                        22.950820
# Mudi                                      33.673469
# Schnauzer                                 21.791768
# Continental Toy Spaniel                   38.636364
# German Spitz                              28.431373
# Andalusian wine-cellar rat-hunting dog    38.019169
# Mini American Shepherd                    35.517241
# Australian Kelpie                         32.926829
# Pyrenean Sheepdog - Smooth Faced          19.277108
# Australian Shepherd                       35.121951
# Chihuahua                                 32.608696

# %%
#SEGUIR ESTUDIANDO: Primeros - Suma podiums - pistas a 0 // Eliminados
