# %% [markdown]
# # Columnas del new dataset para investigar mejor:
#
# - Día (runs --> "type") ✔️
# - Title ✔️
# - Techo (info --> "event"-"conditions"-"Roof") ✔️
# - Suelo (info --> "event"-"conditions"-"Floor") ✔️
# - Manga (runs --> "results"[0]= Agility, "results[1]= Jumping ?) ✔️
# - (runs --> "results[2]= Binominal Info: )
#     - License
#     - Breed
#     - Age
#     - Gender
#     - Hight_cm
#     - Cualification
#     - Speed
#     - Time
#     - Faults
#     - Refusals

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import re

df_agility = pd.read_json("./data/df_agility.json")
df_agility.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 682 entries, 0 to 681
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            682 non-null    object
#  1   shortDate     682 non-null    object
#  2   title         682 non-null    object
#  3   hostClub      682 non-null    object
#  4   location      682 non-null    object
#  5   participants  682 non-null    object
#  6   info          682 non-null    object
#  7   runs          682 non-null    object
#  8   len_runs      682 non-null    int64
#  9   Roof          682 non-null    object
#  10  Floor         682 non-null    object
# dtypes: int64(1), object(10)
# memory usage: 58.7+ KB

# %%
#patron = re.compile(r'.*open.*', re.IGNORECASE)

#indices_a_eliminar = [df_agility[df_agility['title'].str.contains('open', case=False)].index]

#df_agility = df_agility.drop(indices_a_eliminar)
#df_agility.info()

# %%
# Descarto las competiciones que no tienen numero de Licencia de los participantes :S
# Lista de eliminados -> 6 de 682, 23 de 681, 32 de 680, 65 de 679, 67 de 678, 68 de 677, 70 de 676,      

# indices_a_eliminar = [6]
df_agility = df_agility.drop(126)
df_agility.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 681 entries, 0 to 681
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            681 non-null    object
#  1   shortDate     681 non-null    object
#  2   title         681 non-null    object
#  3   hostClub      681 non-null    object
#  4   location      681 non-null    object
#  5   participants  681 non-null    object
#  6   info          681 non-null    object
#  7   runs          681 non-null    object
#  8   len_runs      681 non-null    int64
#  9   Roof          681 non-null    object
#  10  Floor         681 non-null    object
# dtypes: int64(1), object(10)
# memory usage: 63.8+ KB

# %%
# rehacemos el indice:
indice = list(range(681))
df_agility["indice"] = indice
df_agility = df_agility.set_index("indice")

# %%
df_agility["runs"][126]

# %%
Binomial Info': {'Dorsal': '209',
    'Handler': 'Marta Bonet San Emeterio',
    'Dog': 'Gibbs',
    'Breed': 'Spanish Water Dog',
    'Age': '21 months',
    'Gender': 'Female',
    'Height (cm)': '43.0',
    'Studbook name': 'Guardian De Los Sueños',
    'Club': 'Les Fonts',
    'License': '18624',
    'Federation': 'RSCE'}}]

    Dorsal': '207',
    'Handler': 'Maria Jurado',
    'Dog': 'Vuitton',
    'Breed': 'Biewer Terrier',
    'Age': '6 years',
    'Gender': 'Male',
    'Height (cm)': '26.0',
    'Club'

# %%
dic_new_data = {
    "Indice":[],
    "Index_data": [],
    "Fecha":[],     # results --> type
    "Manga":[],     # results --> Agility o Jumping
    # results --> Binominal Info:
    "License":[],   #Licencia identificativa perro
    "Breed":[],     
    "Gender":[],
    "Hight_cm":[],
    "Classification":[],
    "Qualification":[],
    "Speed":[],
    "Time":[],
    "Faults":[],
    "Refusals":[]   
}

# %%
# Nuevo data con todas las Mangas:

lista = list(range(681))
len_lista = []
i = 0
recuento_i = {"Jumping":0, "Agility":0}

for cantidad in lista:
    for diccionario in df_agility["runs"][cantidad]:
        for clave, valor in diccionario["results"][0].items():
            if clave.startswith("Jumping"):
                i += 1
                recuento_i["Jumping"] += 1
                dic_new_data["Indice"].append(i-1)
                dic_new_data["Index_data"].append(cantidad)
                dic_new_data["Fecha"].append(diccionario["type"])
                dic_new_data["Manga"].append(clave)
                dic_new_data["Classification"].append(valor["Classification"])
                dic_new_data["Qualification"].append(valor["Qualification"])
                dic_new_data["Speed"].append(valor["Speed"])
                dic_new_data["Time"].append(valor["Time"]) 
                dic_new_data["Faults"].append(valor["Faults"]) 
                dic_new_data["Refusals"].append(valor["Refusals"])

                
            
            if clave.startswith("Agility"):
                i += 1
                recuento_i["Agility"] += 1
                dic_new_data["Indice"].append(i-1)
                dic_new_data["Index_data"].append(cantidad)
                dic_new_data["Fecha"].append(diccionario["type"])
                dic_new_data["Manga"].append(clave)
                dic_new_data["Classification"].append(valor["Classification"])
                dic_new_data["Qualification"].append(valor["Qualification"])
                dic_new_data["Speed"].append(valor["Speed"])
                dic_new_data["Time"].append(valor["Time"]) 
                dic_new_data["Faults"].append(valor["Faults"]) 
                dic_new_data["Refusals"].append(valor["Refusals"])

                
            
            if clave == "Binomial Info":
                numero_mangas = recuento_i['Jumping'] + recuento_i['Agility']
                for key in valor.keys():
                    while numero_mangas > 0:
                        if len(valor) > 9:
                            print(len(valor))
                            dic_new_data["License"].append(valor["License"])
                            dic_new_data["Breed"].append(valor["Breed"])
                            dic_new_data["Gender"].append(valor["Gender"])
                            dic_new_data["Hight_cm"].append(valor["Height (cm)"])
                        if len(valor) <= 9:
                            dic_new_data["License"].append("PRE")
                            dic_new_data["Breed"].append(valor["Breed"])
                            dic_new_data["Gender"].append(valor["Gender"])
                            dic_new_data["Hight_cm"].append(valor["Height (cm)"])
                             
                        ejecuciones += 1
                        numero_mangas -= 1
                recuento_i = {"Jumping": 0, "Agility": 0}
# Out:
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 12
# 12
# 11
# 11
# 10
# 10
# 11
# 11
# 10
# 10
# 11
# 11
# 11
# 11
# 10
# 10
# 10
# 10
# 11
# 11
# 11
# 11
# 10
# 10
# 10
# 10
# 11
# 11
# 11
# 11
# 10
# 10
# 12
# 12
# 11
# 11
# 10
# 10
# 11
# 11
# 10
# 10
# 11
# 11
# 11
# 11
# 12
# 12
# 11
# 11
# 12
# 12
# 11
# 11
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 11
# 11
# 10
# 10
# 11
# 11
# 10
# 10
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 10
# 10
# 11
# 11
# 10
# 10
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 12
# 12
# 11
# 11
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 11
# 11
# 12
# 12
# 11
# 11
# 12
# 12
# 12
# 12
# 10
# 10
# 11
# 11
# 11
# 11
# 11
# 11
# 10
# 10
# 11
# 11
# 11
# 11
# 10
# 10
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 10
# 10
# 10
# 10
# 10
# 10
# 11
# 11
# 11
# 11
# 11
# 11
# ...

# %%
len(dic_new_data["License"])
# Out:
# 35560

# %%
dic_new_data["Index_data"][-1]
# Out:
# 680

# %%
len(dic_new_data["Indice"])
# Out:
# 35560

# %%
                x = True
                while x == True:
                    if diferencia != 0:
                        diferencia -= 1
                    else:
                        x = False

# %%
data_runs = pd.DataFrame(dic_new_data)
data_runs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35560 entries, 0 to 35559
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Indice          35560 non-null  int64
#  1   Index_data      35560 non-null  int64
#  2   Fecha           35560 non-null  object
#  3   Manga           35560 non-null  object
#  4   License         35560 non-null  object
#  5   Breed           35560 non-null  object
#  6   Gender          35560 non-null  object
#  7   Hight_cm        35560 non-null  object
#  8   Classification  35560 non-null  object
#  9   Qualification   35560 non-null  object
#  10  Speed           35560 non-null  object
#  11  Time            35560 non-null  object
#  12  Faults          35560 non-null  object
#  13  Refusals        35560 non-null  object
# dtypes: int64(2), object(12)
# memory usage: 3.8+ MB

# %%
data_runs.to_json("data_runs.json", orient="records")

# %%
data_runs.head(10)
# Out:
#    Indice  Index_data           Fecha    Manga               License  \
# 0       0           0  Sabado 6 abril  Jumping  2023280386PS88000015
# 1       1           0  Sabado 6 abril  Agility  2023280386PS88000015
# 2       2           0  Sabado 6 abril  Jumping  2022160138RS70000004
# 3       3           0  Sabado 6 abril  Agility  2022160138RS70000004
# 4       4           0  Sabado 6 abril  Jumping  2018160135RS70000001
# 5       5           0  Sabado 6 abril  Agility  2018160135RS70000001
# 6       6           0  Sabado 6 abril  Jumping  2018160135RS70000009
# 7       7           0  Sabado 6 abril  Agility  2018160135RS70000009
# 8       8           0  Sabado 6 abril  Jumping  2023280386PS88000015
# 9       9           0  Sabado 6 abril  Agility  2023280386PS88000015
#
#                      Breed  Gender Hight_cm Classification Qualification  \
# 0  Continental Toy Spaniel    Male     24.5              -          DISQ
# ...
